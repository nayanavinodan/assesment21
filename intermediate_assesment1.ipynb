# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("/content/diabetes_model.csv")

# %%
print(df1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5       77             82             41       42  35.8
# 1              9      122             56              0        0  33.3
# 2              0      113             76              0        0  33.3
# 3              1      139             62             41      480  40.7
# 4             10      161             68             23      132  25.5
# ..           ...      ...            ...            ...      ...   ...
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.156   35        0
# ...

# %%
df2 = pd.read_csv("/content/ny-flights.csv")

# %%
print(df2)
# Out:
#                    fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0      2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1      2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2      2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3      2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4      2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
# ...                    ...            ...         ...      ...     ...    ...
# 20812  2014-01-31 00:00:00             UA       19977   N54711    1253    ROC
# 20813  2014-01-31 00:00:00             UA       19977   N77525    1429    LGA
# 20814  2014-01-31 00:00:00             UA       19977   N37293    1456    LGA
# 20815  2014-01-31 00:00:00             UA       19977   N24729    1457    LGA
# 20816  2014-01-31 00:00:00             MQ       20398   N609MQ    3699    BUF
#
# ...

# %%
combined_df = pd.concat([df1,df2],ignore_index=True)
combined_df
# Out:
#        Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5.0     77.0           82.0           41.0     42.0  35.8
# 1              9.0    122.0           56.0            0.0      0.0  33.3
# 2              0.0    113.0           76.0            0.0      0.0  33.3
# 3              1.0    139.0           62.0           41.0    480.0  40.7
# 4             10.0    161.0           68.0           23.0    132.0  25.5
# ...            ...      ...            ...            ...      ...   ...
# 21426          NaN      NaN            NaN            NaN      NaN   NaN
# 21427          NaN      NaN            NaN            NaN      NaN   NaN
# 21428          NaN      NaN            NaN            NaN      NaN   NaN
# 21429          NaN      NaN            NaN            NaN      NaN   NaN
# 21430          NaN      NaN            NaN            NaN      NaN   NaN
#
#        DiabetesPedigreeFunction   Age  Outcome              fl_date  ...  \
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21431 entries, 0 to 21430
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               614 non-null    float64
#  1   Glucose                   614 non-null    float64
#  2   BloodPressure             614 non-null    float64
#  3   SkinThickness             614 non-null    float64
#  4   Insulin                   614 non-null    float64
#  5   BMI                       614 non-null    float64
#  6   DiabetesPedigreeFunction  614 non-null    float64
#  7   Age                       614 non-null    float64
#  8   Outcome                   614 non-null    float64
#  9   fl_date                   20817 non-null  object
#  10  unique_carrier            20817 non-null  object
#  11  airline_id                20817 non-null  float64
#  12  tail_num                  20512 non-null  object
# ...

# %%
combined_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   614.000000  614.000000     614.000000     614.000000  614.000000
# mean      3.845277  121.500000      69.599349      20.400651   79.035831
# std       3.403362   32.275918      18.924485      16.113962  117.108037
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.500000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      22.500000   24.000000
# 75%       6.000000  141.000000      80.000000      33.000000  127.500000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome  \
# count  614.000000                614.000000  614.000000  614.000000
# mean    32.210423                  0.476373   33.289902    0.350163
# std      7.965291                  0.343502   11.837425    0.477410
# ...

# %%
combined_df.isnull().sum()
# Out:
# Pregnancies                 20817
# Glucose                     20817
# BloodPressure               20817
# SkinThickness               20817
# Insulin                     20817
# BMI                         20817
# DiabetesPedigreeFunction    20817
# Age                         20817
# Outcome                     20817
# fl_date                       614
# unique_carrier                614
# airline_id                    614
# tail_num                      919
# fl_num                        614
# origin                        614
# dest                          614
# dep_time                     2969
# dep_delay                    2969
# arr_time                     3019
# arr_delay                    3048
# cancelled                     614
# arr                          3019
# dep                          2969
# dtype: int64

# %%
combined_df.duplicated().sum()
# Out:
# 0

# %%
combined_df.drop_duplicates(inplace=True)

# %%
combined_df.duplicated().sum()
# Out:
# 0

# %%
combined_df.shape
# Out:
# (21431, 23)

# %%
combined_df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome', 'fl_date',
#        'unique_carrier', 'airline_id', 'tail_num', 'fl_num', 'origin', 'dest',
#        'dep_time', 'dep_delay', 'arr_time', 'arr_delay', 'cancelled', 'arr',
#        'dep'],
#       dtype='object')

# %%
combined_df.dtypes
# Out:
# Pregnancies                 float64
# Glucose                     float64
# BloodPressure               float64
# SkinThickness               float64
# Insulin                     float64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                         float64
# Outcome                     float64
# fl_date                      object
# unique_carrier               object
# airline_id                  float64
# tail_num                     object
# fl_num                      float64
# origin                       object
# dest                         object
# dep_time                    float64
# dep_delay                   float64
# arr_time                    float64
# arr_delay                   float64
# cancelled                   float64
# arr                          object
# dep                          object
# dtype: object

# %%
combined_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          5.0     77.0           82.0           41.0     42.0  35.8
# 1          9.0    122.0           56.0            0.0      0.0  33.3
# 2          0.0    113.0           76.0            0.0      0.0  33.3
# 3          1.0    139.0           62.0           41.0    480.0  40.7
# 4         10.0    161.0           68.0           23.0    132.0  25.5
#
#    DiabetesPedigreeFunction   Age  Outcome fl_date  ... fl_num  origin dest  \
# 0                     0.156  35.0      0.0     NaN  ...    NaN     NaN  NaN
# 1                     1.114  33.0      1.0     NaN  ...    NaN     NaN  NaN
# 2                     0.278  23.0      1.0     NaN  ...    NaN     NaN  NaN
# 3                     0.536  21.0      0.0     NaN  ...    NaN     NaN  NaN
# 4                     0.326  47.0      1.0     NaN  ...    NaN     NaN  NaN
#
#    dep_time dep_delay arr_time  arr_delay  cancelled  arr  dep
# ...

# %%
combined_df.tail()
# Out:
#        Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 21426          NaN      NaN            NaN            NaN      NaN  NaN
# 21427          NaN      NaN            NaN            NaN      NaN  NaN
# 21428          NaN      NaN            NaN            NaN      NaN  NaN
# 21429          NaN      NaN            NaN            NaN      NaN  NaN
# 21430          NaN      NaN            NaN            NaN      NaN  NaN
#
#        DiabetesPedigreeFunction  Age  Outcome              fl_date  ...  \
# 21426                       NaN  NaN      NaN  2014-01-31 00:00:00  ...
# 21427                       NaN  NaN      NaN  2014-01-31 00:00:00  ...
# 21428                       NaN  NaN      NaN  2014-01-31 00:00:00  ...
# 21429                       NaN  NaN      NaN  2014-01-31 00:00:00  ...
# 21430                       NaN  NaN      NaN  2014-01-31 00:00:00  ...
#
#        fl_num  origin dest  dep_time dep_delay arr_time  arr_delay  cancelled  \
# ...

# %%
combined_df['Age'].value_counts()
# Out:
# Age
# 22.0    57
# 21.0    50
# 25.0    42
# 24.0    36
# 23.0    31
# 26.0    28
# 28.0    26
# 27.0    25
# 29.0    23
# 31.0    20
# 41.0    18
# 30.0    17
# 33.0    15
# 37.0    14
# 43.0    13
# 45.0    13
# 46.0    13
# 42.0    13
# 34.0    11
# 32.0    11
# 40.0    10
# 38.0    10
# 39.0     9
# 35.0     9
# 36.0     8
# 52.0     8
# 44.0     7
# 51.0     6
# 47.0     6
# 58.0     6
# 50.0     5
# 48.0     5
# 53.0     5
# 66.0     4
# 49.0     4
# 60.0     4
# 63.0     3
# 54.0     3
# 62.0     3
# 57.0     3
# 59.0     3
# 56.0     3
# 55.0     3
# 65.0     2
# 67.0     2
# 61.0     1
# 70.0     1
# 68.0     1
# 69.0     1
# 64.0     1
# 81.0     1
# 72.0     1
# Name: count, dtype: int64

# %%
combined_df["fl_num"].mean()
# Out:
# 1826.0988134697602

# %%
combined_df["fl_num"].median()
# Out:
# 1457.0

# %%
combined_df["fl_num"].mode()
# Out:
# 0    3.0
# Name: fl_num, dtype: float64

# %%
df1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            5       77             82             41       42  35.8
# 1            9      122             56              0        0  33.3
# 2            0      113             76              0        0  33.3
# 3            1      139             62             41      480  40.7
# 4           10      161             68             23      132  25.5
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.156   35        0
# 1                     1.114   33        1
# 2                     0.278   23        1
# 3                     0.536   21        0
# 4                     0.326   47        1

# %%
df1.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 609                     0.126   24        0
# 610                     0.326   22        0
# 611                     0.127   25        1
# 612                     0.647   51        0
# 613                     0.238   32        1

# %%
df1.shape
# Out:
# (614, 9)

# %%
# que2

# %%
df1.plot(kind="box")
# Out:
# <Axes: >

# %%
df2.plot.scatter(x="dep_delay",y="arr_delay")
df2
# Out:
#                    fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0      2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1      2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2      2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3      2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4      2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
# ...                    ...            ...         ...      ...     ...    ...
# 20812  2014-01-31 00:00:00             UA       19977   N54711    1253    ROC
# 20813  2014-01-31 00:00:00             UA       19977   N77525    1429    LGA
# 20814  2014-01-31 00:00:00             UA       19977   N37293    1456    LGA
# 20815  2014-01-31 00:00:00             UA       19977   N24729    1457    LGA
# 20816  2014-01-31 00:00:00             MQ       20398   N609MQ    3699    BUF
#
# ...

# %%
df1.plot.scatter(x="Age",y="Glucose")
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5       77             82             41       42  35.8
# 1              9      122             56              0        0  33.3
# 2              0      113             76              0        0  33.3
# 3              1      139             62             41      480  40.7
# 4             10      161             68             23      132  25.5
# ..           ...      ...            ...            ...      ...   ...
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.156   35        0
# ...

# %%
df2.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2['fl_num'].corr(df2['dep_delay'])
# Out:
# 0.0036621202054906887

# %%
df2['fl_num'].cov(df2['dep_delay'])
# Out:
# 329.16453694971733

# %%
df1['Age'].corr(df1['Glucose'])
# Out:
# 0.25187326683363764

# %%
df2['dep_delay'].corr(df2['arr_delay'])
# Out:
# 0.9523804093089614
